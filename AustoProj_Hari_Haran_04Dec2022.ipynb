# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.21.5
# 1.4.2
# 0.11.2

# %%
# Read the dataset
austo = pd.read_csv('austo_automobile+29+29.csv')

# %%
austo.shape
# Out:
# (1581, 14)

# %%
austo.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
austo.tail()
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1576   22   Male   Salaried         Single  Graduate                 2
# 1577   22   Male   Business        Married  Graduate                 4
# 1578   22   Male   Business         Single  Graduate                 2
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1576            No        Yes              No   33300             0.0
# 1577            No         No              No   32000             NaN
# 1578            No        Yes              No   32900             0.0
# 1579           Yes        Yes              No   32200             NaN
# 1580            No         No              No   31600             0.0
#
#       Total_salary  Price       Make
# 1576         33300  27000  Hatchback
# 1577         32000  31000  Hatchback
# ...

# %%
austo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
austo.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     31.922201      8.425978     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  60392.220114  14674.825044  30000.0  51900.0
# Partner_salary    1475.0  20225.559322  19573.149277      0.0      0.0
# Total_salary      1581.0  79625.996205  25545.857768  30000.0  60500.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      54.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59500.0  71800.0   99300.0
# Partner_salary    25600.0  38300.0   80500.0
# Total_salary      78000.0  95900.0  171000.0
# Price             31000.0  47000.0   70000.0

# %%
austo.describe(include="all").T
# Out:
#                    count unique            top  freq          mean  \
# Age               1581.0    NaN            NaN   NaN     31.922201
# Gender              1528      4           Male  1199           NaN
# Profession          1581      2       Salaried   896           NaN
# Marital_status      1581      2        Married  1443           NaN
# Education           1581      2  Post Graduate   985           NaN
# No_of_Dependents  1581.0    NaN            NaN   NaN      2.457938
# Personal_loan       1581      2            Yes   792           NaN
# House_loan          1581      2             No  1054           NaN
# Partner_working     1581      2            Yes   868           NaN
# Salary            1581.0    NaN            NaN   NaN  60392.220114
# Partner_salary    1475.0    NaN            NaN   NaN  20225.559322
# Total_salary      1581.0    NaN            NaN   NaN  79625.996205
# Price             1581.0    NaN            NaN   NaN   35597.72296
# ...

# %%
# Checking for duplicate values
dups = austo.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
austo[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [Age, Gender, Profession, Marital_status, Education, No_of_Dependents, Personal_loan, House_loan, Partner_working, Salary, Partner_salary, Total_salary, Price, Make]
# Index: []

# %%
#Checking for null values
austo.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %% [markdown]
# - Gender and Partner_salary has null values. And it needs to be treated before further analysis of the data.
# - All others have no null values.

# %% [markdown]
# ##### Observations:
#
# - Dataset has **1581 columns** and **14 rows**
# - Dataset has integer, float and object data types. Total **int type** = 5, **float type** = 1, **object type** = 8.
# - No **_duplicate_** records (values) are found.
# - There are no negative numerical values.
# - Gender has missing values which needs to be treated. **Female** has non-null values and have different letter sizes.
# - Data of **partner_salary** is non-null values which needs to be treated.
# - Dataset provided is for owners with purchases of different makes of automobile which can be analysed.
# - From the data set we can also relate the price of the automobile depending on their salary, partner's salary and loan.
# - We can also generate an insight based on their proffession, price of the automobiles and make choices
# - Gender based automobile choices can be also be visualised
# - Loans(house and personal) can give insight on the buying behavior of customers and price range.

# %% [markdown]
# ### Treating Missing values or Bad Data in the data set

# %% [markdown]
# ##### Treating Missing or bad values in Gender Column

# %%
#lets treat the Bad data of Gender.
austo["Gender"].value_counts()
# Out:
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: Gender, dtype: int64

# %%
austo['Gender'] = austo['Gender'].str.replace('Femal', 'Female')

# %%
austo['Gender'] = austo['Gender'].str.replace('Femle', 'Female')

# %%
austo["Gender"].value_counts()
# Out:
# Male       1199
# Femalee     327
# Female        2
# Name: Gender, dtype: int64

# %%
austo['Gender'] = austo['Gender'].str.replace('Femalee', 'Female')

# %%
austo["Gender"].value_counts()
# Out:
# Male      1199
# Female     329
# Name: Gender, dtype: int64

# %% [markdown]
# - We have sucessfully corrected the spelling for Female in **Gender** column

# %%
#Fxing nan value
austo['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
austo_imputed = austo.copy()

# %%
austo_imputed.dropna(subset='Gender', inplace = True)

# %%
austo_imputed
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %% [markdown]
# - Since there are low are missing data in gender, we have dropped the rows with nan value

# %%
austo_imputed.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      103
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %% [markdown]
# - So there are no missing values now in the Gender column

# %%
austo_imputed["Gender"].value_counts()
# Out:
# Male      1199
# Female     329
# Name: Gender, dtype: int64

# %%
austo_imputed['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
austo_imputed.Gender.describe()
# Out:
# count     1528
# unique       2
# top       Male
# freq      1199
# Name: Gender, dtype: object

# %% [markdown]
# - Two unique values - Male and Female are set

# %%
plt.title('Gender')
plt.xlabel('Gender')
sns.countplot(data=austo, x='Gender',color='orange');

# %%
austo_imputed.reset_index(drop= True)
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1523   22    Male   Salaried         Single       Graduate                 2
# 1524   22    Male   Business        Married       Graduate                 4
# 1525   22    Male   Business         Single       Graduate                 2
# 1526   22    Male   Business        Married       Graduate                 3
# 1527   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %% [markdown]
# - We have treated the missing Gender values in the data set.
# - There are 2 unique values Male and Female genders, that's all we need
# - We also need to reset and drop the old index to get 1528 rows and 15

# %%
#Checking again for null values
austo_imputed.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %% [markdown]
# - Partner_salary have missing values

# %%
#checking for outliers
sns.boxplot(data=austo_imputed, x='Partner_salary',color='orange');

# %% [markdown]
# - As per the above plot there are no outliers

# %% [markdown]
# #### Treating Missing or bad values in "*Partner_salary*" Column

# %%
austo_imputed["Partner_salary"].value_counts().head(10)
# Out:
# 0        690
# 40500     28
# 40200     27
# 40000     25
# 40100     25
# 40800     23
# 40900     23
# 40400     22
# 40600     21
# 40300     20
# Name: Partner_salary, dtype: int64

# %%
austo_imputed['Partner_salary'].unique()
# Out:
# array([70700., 70300., 60700., 60200., 60500., 50800., 40400.,     0.,
#        70600., 60600., 60300., 45500., 40200., 40700., 27800., 70000.,
#        40100., 40900., 27000.,    nan, 40500., 50400., 80400., 60900.,
#        60100., 70200., 40300., 40800., 70800.,   900., 45000., 40600.,
#        50700., 80500., 27700., 35800., 26600., 60000., 27900., 60800.,
#        40000., 70100., 38100., 38200., 30200., 38500., 30000., 50900.,
#        35100., 38700., 38300., 38900., 23200., 24700., 30800., 28100.,
#        38400., 38000., 23100., 30100., 25700., 70400.,   200., 30900.,
#        26100., 45700.,   400., 28200., 70900., 38800., 45200., 26800.,
#        60400., 30300., 25800.,   800., 38600., 24500., 30700., 28500.,
#        24900., 70500., 35900., 30500., 28900., 27200., 45900., 25300.,
#        35600., 25200., 26300., 35700., 23800., 32700., 30600., 45600.,
#        28000.,   600., 32600., 28600., 25100., 26700., 24200.,   700.,
# ...

# %%
austo_imputed['Partner_salary'].describe()
# Out:
# count     1425.000000
# mean     20522.877193
# std      19656.146189
# min          0.000000
# 25%          0.000000
# 50%      25800.000000
# 75%      38400.000000
# max      80500.000000
# Name: Partner_salary, dtype: float64

# %%
austo_imputed[austo_imputed['Partner_salary'] .isna()]
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 40     53  Female   Salaried        Married       Graduate                 1
# 43     52    Male   Salaried        Married  Post Graduate                 3
# 49     52  Female   Business        Married  Post Graduate                 4
# 59     54    Male   Salaried        Married       Graduate                 3
# 111    48  Female   Business        Married       Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1559   22    Male   Business        Married  Post Graduate                 3
# 1567   22    Male   Salaried         Single       Graduate                 0
# 1568   22    Male   Salaried        Married       Graduate                 3
# 1577   22    Male   Business        Married       Graduate                 4
# 1579   22    Male   Business        Married       Graduate                 3
#
# ...

# %% [markdown]
# - We see that some partner_working = Yes, has NaN values which cannot have 0 value as Partner_salary. So we need to treat these values.
# - We need to replace partner_working = No, Has NaN values which should have 0 value as Partner_salary. So we need to impute them as 0

# %%
austo_imputed['Partner_salary'] = austo_imputed['Partner_salary'].fillna(0)

# %%
austo_imputed.tail(2)
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1579           Yes        Yes              No   32200               0
# 1580            No         No              No   31600               0
#
#       Total_salary  Price       Make
# 1579         32200  24000  Hatchback
# 1580         31600  31000  Hatchback

# %% [markdown]
# - we have sucessfully replace all nan values to 0 for **Partner_salary** .

# %%
austo_imputed['Partner_salary']=austo_imputed['Total_salary']-austo_imputed['Salary']
austo_imputed.tail(10)
# Out:
#       Age Gender Profession Marital_status Education  No_of_Dependents  \
# 1571   22   Male   Business        Married  Graduate                 3
# 1572   22   Male   Business         Single  Graduate                 2
# 1573   22   Male   Business        Married  Graduate                 3
# 1574   22   Male   Salaried        Married  Graduate                 3
# 1575   22   Male   Salaried        Married  Graduate                 3
# 1576   22   Male   Salaried         Single  Graduate                 2
# 1577   22   Male   Business        Married  Graduate                 4
# 1578   22   Male   Business         Single  Graduate                 2
# 1579   22   Male   Business        Married  Graduate                 3
# 1580   22   Male   Salaried        Married  Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1571            No         No              No   36000               0
# ...

# %%
austo_imputed.Partner_salary.isnull().sum()
# Out:
# 0

# %%
austo_imputed.reset_index(drop= True)
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53  Female   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1523   22    Male   Salaried         Single       Graduate                 2
# 1524   22    Male   Business        Married       Graduate                 4
# 1525   22    Male   Business         Single       Graduate                 2
# 1526   22    Male   Business        Married       Graduate                 3
# 1527   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
austo_imputed["Gender"]= np.where(austo_imputed["Gender"] == "Female", 0, 1)

# %%
austo_imputed.Gender.dtype
# Out:
# dtype('int32')

# %%
austo_imputed.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53       1   Business        Married  Post Graduate                 4
# 1   53       0   Salaried        Married  Post Graduate                 4
# 2   53       0   Salaried        Married  Post Graduate                 3
# 3   53       0   Salaried        Married       Graduate                 2
# 4   53       1   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300           70700
# 1           Yes         No             Yes   95500           70300
# 2            No         No             Yes   97300           60700
# 3           Yes         No             Yes   72500           70300
# 4            No         No             Yes   79700           60200
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %% [markdown]
# - we have replaced Gender  Male = 1
# - we have replaced Gender Female = 0

# %%
sns.countplot(data=austo_imputed, x='Make');

# %%
austo_imputed["Make"].value_counts()
# Out:
# Sedan        657
# Hatchback    580
# SUV          291
# Name: Make, dtype: int64

# %% [markdown]
# - Sedan has the highest record of purchases = 657
# - Hatcback is second = 580
# - Suv is lowest = 291

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=austo_imputed, x='Make', hue = 'Gender');

# %% [markdown]
# ####  Insights
# - 0 in the plot indicates '**Female**' customers who have opted for **SUV** with highest purchase. They also like **Sedan** make. They prefer **SUV** mostly.
#
# - From the above plot '**Female**' we can also see derive that there only few female customers and more '**Male**' customers.
#
# - 1 in the plot indicates '**Male**' customers who have opted for **Hatchback** with highest purchase. They also like sedan class.
#
# - From the above plot we can also understand that both genders who are salaried like **Sedan** make on an average.

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=austo_imputed, x='Make', hue = 'Profession');

# %% [markdown]
# #### Insights
# - Salaried people prefer **Sedan** class more than **Business** class.
# - **Business** class prefer both **Sedan** and **Hatcback** almost the equally.
# - Salaried and Business both like the hatchback same

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=austo_imputed, x='Price',color='orange');

# %% [markdown]
# - No outliers found

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=austo_imputed, x='Price', kde = True);

# %%
austo_imputed["Price"].mean()
# Out:
# 36022.905759162306

# %% [markdown]
# - The price is right skewed
# - The average Price of the cars are around 36022.91

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=austo_imputed, x='Make',y= 'Price');

# %%
plt.figure(figsize=(10,8))
sns.heatmap(austo_imputed.corr(),annot=True,fmt=".2f");

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=austo_imputed, x='Make', hue = 'Marital_status');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(15,5)
sns.countplot(data=austo_imputed, x='Make', hue = 'Marital_status', ax=axes[0])
sns.countplot(data=austo_imputed, x='Make', hue = 'Gender', ax=axes[1])
plt.show();

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(15,5)
sns.countplot(data=austo_imputed, x='Make', hue = 'Marital_status', ax=axes[0])
sns.countplot(data=austo_imputed, x='Gender', hue = 'Marital_status', ax=axes[1])
plt.show();

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=austo_imputed, x="Total_salary", y="Price", hue="Partner_working");
plt.legend(bbox_to_anchor=[0,0]);

# %% [markdown]
# - The above plot shows that people with working partner do prefer to buy higher-priced cars.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=austo_imputed, x='Age', y = 'Price');

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=austo_imputed, x='Total_salary', y = 'Price');

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=austo_imputed, x='Make', y = 'Age', hue = 'Marital_status');

# %%
sns.pairplot(austo_imputed);

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=austo_imputed, x='Gender', y = 'Salary');

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=austo_imputed, x='Gender', y = 'Total_salary');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(15,5)
sns.boxplot(data=austo_imputed, x='Gender', y = 'Total_salary', ax=axes[0])
sns.boxplot(data=austo_imputed, x='Gender', y = 'Salary', ax=axes[1])
plt.show();

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=austo_imputed, x='Make', hue = 'Personal_loan');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=austo_imputed, x='Make', hue = 'House_loan');

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(15,5)
sns.countplot(data=austo_imputed, x='Make', hue = 'Personal_loan', ax=axes[0])
sns.countplot(data=austo_imputed, x='Make', hue = 'House_loan', ax=axes[1])
plt.show();
